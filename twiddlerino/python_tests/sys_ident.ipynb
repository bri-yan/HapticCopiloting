# %%
import asyncio
from serial_interface.serial_interface import TwidSerialInterfaceProtocol, TelemetryFrame, run_test, ControlType, start_protocol

import os

###SERIAL CONFIGURATION for esp32
SERIAL_PORT = 'COM9'
SERIAL_BAUD_RATE = 1000000

DATA_DIR_PATH = os.path.join(os.getcwd(),'data')

twid = await start_protocol(asyncio.get_event_loop(), SERIAL_PORT, SERIAL_BAUD_RATE)
# Out:
# port opened SerialTransport(<_WindowsSelectorEventLoop running=True closed=False debug=False>, <serial_interface.serial_interface.TwidSerialInterfaceProtocol object at 0x0000029B9C51E870>, Serial<id=0x29b9cda1990, open=True>(port='COM9', baudrate=1000000, bytesize=8, parity='N', stopbits=1, timeout=0, xonxoff=False, rtscts=False, dsrdtr=False))

# %%
#control parameter fitting
import scipy.optimize
import scipy.signal
import numpy as np

import matplotlib.pyplot as plt
import pandas

import control.matlab as control

#MOTOR EMPIRCAL PARAMS

#voltage supply
PWM_AMPLITUDE = 12
DC_STEPS = [128, 256, 512, 1024]

#second order model
def so_model(x,K,wn,zeta):
    tf = control.tf([K],[1,2*wn*zeta,wn**2])
    yout,T = control.step(tf, T=x)
    return yout[-1]

# %%
#reset
await twid.esp32_reboot()
twid.clear_frames()
await twid.update_telem_sample_rate(5)
await twid.update_control_type(ControlType.NO_CTRL)
await twid.wait_for_param('control_type', ControlType.NO_CTRL)
await twid.update_dutycycle(0)
await twid.wait_for_param('pwm_duty_cycle',0)

step_input = 512
#apply step to 512/1024
await twid.update_dutycycle(step_input)
#collect all data for next 5 seconds
dataseries = await twid.collect_telem(5)
print(dataseries)
#stop motor
await twid.motor_stop()

#save as a nice csv using pandas
dataseries.to_csv(os.path.join(DATA_DIR_PATH,f'current_step_response_{step_input}.csv'), index=False)

#collect info from start of step only
ts = dataseries['timestamp_ms'][dataseries['pwm_duty_cycle'] >= step_input]
current = dataseries['filtered_current'][dataseries['pwm_duty_cycle'] >= step_input]
vel = dataseries['filtered_velocity'][dataseries['pwm_duty_cycle'] >= step_input]

#apply curve fitting to get second order params using scipy
[K, wn, zeta],_ = scipy.optimize.curve_fit(so_model, ts.to_numpy(), current.to_numpy())
output_str = f'Step response estimated second order parameters:\n\
    K:{K}\twn:{wn}\tzeta:{zeta}\n'
print(output_str)

[K, wn, zeta],_ = scipy.optimize.curve_fit(so_model, ts.to_numpy(), vel.to_numpy())
output_str = f'Step response estimated second order parameters:\n\
    K:{K}\twn:{wn}\tzeta:{zeta}\n'
print(output_str)
# Out:
#     timestamp_ms  loop_dt  control_dt  read_dt  pwm_duty_cycle  pwm_frequency  \
# 0          451.0   1000.0        28.0     66.0           512.0           -0.0
# 1          456.0    992.0        28.0     66.0           512.0           -0.0
# 2          461.0   1000.0        28.0     66.0           512.0           -0.0
# 3          466.0   1000.0        28.0     66.0           512.0           -0.0
# 4          471.0   1000.0        28.0     66.0           512.0           -0.0
# ..           ...      ...         ...      ...             ...            ...
# 90         991.0   1000.0        16.0     57.0           512.0           -0.0
# 91         996.0   1012.0        17.0     57.0           512.0           -0.0
# 92        1001.0    994.0        25.0     65.0           512.0           -0.0
# 93        1006.0    993.0        25.0     65.0           512.0           -0.0
# 94        1011.0    999.0        16.0     57.0           512.0           -0.0
#
#     position  velocity  filtered_velocity    current  ...    Ki    Kd  \
# 0        0.0       0.0                0.0 -18.382353  ...  0.01  0.01
# 1        0.0       0.0                0.0 -18.382353  ...  0.01  0.01
# 2        0.0       0.0                0.0 -18.382353  ...  0.01  0.01
# 3        0.0       0.0                0.0 -18.382353  ...  0.01  0.01
# 4        0.0       0.0                0.0 -18.382353  ...  0.01  0.01
# ..       ...       ...                ...        ...  ...   ...   ...
# 90       0.0       0.0                0.0 -18.382353  ...  0.01  0.01
# 91       0.0       0.0                0.0 -18.382353  ...  0.01  0.01
# 92       0.0       0.0                0.0 -18.382353  ...  0.01  0.01
# 93       0.0       0.0                0.0 -18.382353  ...  0.01  0.01
# 94       0.0       0.0                0.0 -18.382353  ...  0.01  0.01
#
#     impedance_K  impedance_B  impedance_J  nframes_sent_queue  \
# 0         0.001         0.01     0.000001                82.0
# 1         0.001         0.01     0.000001                83.0
# 2         0.001         0.01     0.000001                84.0
# 3         0.001         0.01     0.000001                85.0
# 4         0.001         0.01     0.000001                86.0
# ..          ...          ...          ...                 ...
# 90        0.001         0.01     0.000001               190.0
# 91        0.001         0.01     0.000001               191.0
# 92        0.001         0.01     0.000001               192.0
# 93        0.001         0.01     0.000001               193.0
# 94        0.001         0.01     0.000001               194.0
#
#     nframes_sent_serial  control_type_val         control_type  \
# 0                  82.0               5.0  ControlType.NO_CTRL
# 1                  83.0               5.0  ControlType.NO_CTRL
# 2                  84.0               5.0  ControlType.NO_CTRL
# 3                  85.0               5.0  ControlType.NO_CTRL
# 4                  86.0               5.0  ControlType.NO_CTRL
# ..                  ...               ...                  ...
# 90                190.0               5.0  ControlType.NO_CTRL
# 91                191.0               5.0  ControlType.NO_CTRL
# 92                192.0               5.0  ControlType.NO_CTRL
# 93                193.0               5.0  ControlType.NO_CTRL
# 94                194.0               5.0  ControlType.NO_CTRL
#
#     current_sens_adc_voltage
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ..                       ...
# 90                         0
# 91                         0
# 92                         0
# 93                         0
# 94                         0
#
# [95 rows x 29 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 28
#      25 vel = dataseries['filtered_velocity'][dataseries['pwm_duty_cycle'] >= step_input]
#      27 #apply curve fitting to get second order params using scipy
# ---> 28 [K, wn, zeta],_ = scipy.optimize.curve_fit(so_model, ts.to_numpy(), current.to_numpy())
#      29 output_str = f'Step response estimated second order parameters:\n\
#      30     K:{K}\twn:{wn}\tzeta:{zeta}\n'
#      31 print(output_str)
#
# File g:\Apps\.python\Lib\site-packages\scipy\optimize\_minpack_py.py:963, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     960 if ydata.size != 1 and n > ydata.size:
#     961     raise TypeError(f"The number of func parameters={n} must not"
#     962                     f" exceed the number of data points={ydata.size}")
# --> 963 res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     964 popt, pcov, infodict, errmsg, ier = res
#     965 ysize = len(infodict['fvec'])
#
# File g:\Apps\.python\Lib\site-packages\scipy\optimize\_minpack_py.py:415, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     413 if not isinstance(args, tuple):
#     414     args = (args,)
# --> 415 shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     416 m = shape[0]
#     418 if n > m:
#
# File g:\Apps\.python\Lib\site-packages\scipy\optimize\_minpack_py.py:25, in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      23 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      24                 output_shape=None):
# ---> 25     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      26     if (output_shape is not None) and (shape(res) != output_shape):
#      27         if (output_shape[0] != 1):
#
# File g:\Apps\.python\Lib\site-packages\scipy\optimize\_minpack_py.py:507, in _lightweight_memoizer.<locals>._memoized_func(params)
#     504 if np.all(_memoized_func.last_params == params):
#     505     return _memoized_func.last_val
# --> 507 val = f(params)
#     509 if _memoized_func.last_params is None:
#     510     _memoized_func.last_params = np.copy(params)
#
# File g:\Apps\.python\Lib\site-packages\scipy\optimize\_minpack_py.py:523, in _wrap_func.<locals>.func_wrapped(params)
#     522 def func_wrapped(params):
# --> 523     return func(xdata, *params) - ydata
#
# Cell In[2], line 10, in so_model(x, K, wn, zeta)
#       9 def so_model(x,K,wn,zeta):
# ---> 10     return scipy.signal.lti([K],[1, 2*wn*zeta, wn**2]).step(T=x)[1]
#
# File g:\Apps\.python\Lib\site-packages\scipy\signal\_ltisys.py:245, in lti.step(self, X0, T, N)
#     240 def step(self, X0=None, T=None, N=None):
#     241     """
#     242     Return the step response of a continuous-time system.
#     243     See `step` for details.
#     244     """
# --> 245     return step(self, X0=X0, T=T, N=N)
#
# File g:\Apps\.python\Lib\site-packages\scipy\signal\_ltisys.py:2463, in step(system, X0, T, N)
#    2461     T = asarray(T)
#    2462 U = ones(T.shape, sys.A.dtype)
# -> 2463 vals = lsim(sys, U, T, X0=X0, interp=False)
#    2464 return vals[0], vals[1]
#
# File g:\Apps\.python\Lib\site-packages\scipy\signal\_ltisys.py:2121, in lsim(system, U, T, X0, interp)
#    2119 dt = T[1] - T[0]
#    2120 if not np.allclose(np.diff(T), dt):
# -> 2121     raise ValueError("Time steps are not equally spaced.")
#    2123 if no_input:
#    2124     # Zero input: just use matrix exponential
#    2125     # take transpose because state is a row vector
#    2126     expAT_dt = linalg.expm(transpose(A) * dt)
#
# ValueError: Time steps are not equally spaced.
